# %%
import pandas as pd
import time
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Members

# %%
members_df = pd.read_csv("members_v3.csv") # 6,769,473 observations are loadable into memory.

# %%
members_df.head()
# Out:
#                                            msno  city  bd  gender  \
# 0  Rb9UwLQTrxzBVwCB6+bCcSQWZ9JiNLC9dXtM1oEsZA8=     1   0     NaN
# 1  +tJonkh+O1CA796Fm5X60UMOtB6POHAwPjbTRVl/EuU=     1   0     NaN
# 2  cV358ssn7a0f7jZOwGNWS07wCKVqxyiImJUX6xcIwKw=     1   0     NaN
# 3  9bzDeJP6sQodK73K5CBlJ6fgIQzPeLnRl0p5B77XP+g=     1   0     NaN
# 4  WFLY3s7z4EZsieHCt63XrsdtfTEmJ+2PnnKLH5GY4Tk=     6  32  female
#
#    registered_via  registration_init_time
# 0              11                20110911
# 1               7                20110914
# 2              11                20110915
# 3              11                20110915
# 4               9                20110915

# %%
# replace the gender column into female, male, nan
members_df = pd.concat([members_df.drop('gender', axis=1), pd.get_dummies(members_df['gender'], dummy_na=True)], axis=1)
# rename bd -> age
members_df = members_df.rename(columns={"bd":"age"})

# %% [markdown]
# ## Transactions

# %%
transactions_df = pd.read_csv("big/transactions.csv") # 21,547,748 observations are loadable into memory.

# %%
transactions_df.head()
# Out:
#                                            msno  payment_method_id  \
# 0  YyO+tlZtAXYXoZhNr3Vg3+dfVQvrBVGO8j1mfqe4ZHc=                 41
# 1  AZtu6Wl0gPojrEQYB8Q3vBSmE2wnZ3hi1FbK1rQQ0A4=                 41
# 2  UkDFI97Qb6+s2LWcijVVv4rMAsORbVDT2wNXF0aVbns=                 41
# 3  M1C56ijxozNaGD0t2h68PnH2xtx5iO5iR2MVYQB6nBI=                 39
# 4  yvj6zyBUaqdbUQSrKsrZ+xNDVM62knauSZJzakS9OW4=                 39
#
#    payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 0                 30              129                 129              1
# 1                 30              149                 149              1
# 2                 30              129                 129              1
# 3                 30              149                 149              1
# 4                 30              149                 149              1
#
#    transaction_date  membership_expire_date  is_cancel
# 0          20150930                20151101          0
# 1          20150930                20151031          0
# 2          20150930                20160427          0
# 3          20150930                20151128          0
# 4          20150930                20151121          0

# %% [markdown]
# ## User logs

# %%
user_logs_df = pd.read_csv("big/user_logs.csv", chunksize=5000000) # 392,106,543 observation are too large to load into memory at once. Load 500000 observations per chunk.

# %%
user_data = pd.DataFrame()

start_time = time.time()

for i, chunk in enumerate(user_logs_df):
    merged = members_df.merge(chunk, on='msno', how='inner')
    user_data = pd.concat([user_data, merged])

    print("Loop ",i,"took %s seconds" % (time.time() - start_time))
# Out:
# Loop  0 took 12.978417873382568 seconds
# Loop  1 took 27.51682472229004 seconds
# Loop  2 took 45.69872689247131 seconds
# Loop  3 took 65.11366081237793 seconds
# Loop  68 took 16217.051433801651 seconds
# Loop  69 took 16694.140466928482 seconds
# Loop  70 took 17167.39451789856 seconds
# Loop  71 took 17678.281332969666 seconds
# Loop  72 took 18188.182792901993 seconds
# Loop  73 took 18717.455214738846 seconds
# Loop  74 took 19257.104255914688 seconds
# Loop  75 took 19799.28012895584 seconds
# Loop  76 took 20352.54010796547 seconds
# Loop  77 took 20932.590491771698 seconds
# Loop  78 took 21531.77196598053 seconds

# %%
user_data.head()
# Out:
#                                            msno  city  age  registered_via  \
# 0  WH5Jq4mgtfUFXh2yz+HrcTXKS4Oess4k4W3qKolAeb0=     5   34               9
# 1  I0yFvqMoNkM8ZNHb617e1RBzIS/YRKemHO7Wj13EtA0=    13   63               9
# 2  I0yFvqMoNkM8ZNHb617e1RBzIS/YRKemHO7Wj13EtA0=    13   63               9
# 3  I0yFvqMoNkM8ZNHb617e1RBzIS/YRKemHO7Wj13EtA0=    13   63               9
# 4  I0yFvqMoNkM8ZNHb617e1RBzIS/YRKemHO7Wj13EtA0=    13   63               9
#
#    registration_init_time  female  male  NaN      date  num_25  num_50  \
# 0                20110916       0     1    0  20161003       5       1
# 1                20110918       0     1    0  20150103       0       0
# 2                20110918       0     1    0  20150522       2       0
# 3                20110918       0     1    0  20151016       2       1
# 4                20110918       0     1    0  20160131       1       0
#
#    num_75  num_985  num_100  num_unq  total_secs
# 0       1        0       16       20    4294.178
# 1       0        0        1        1     229.616
# 2       0        1       18       19    4686.103
# 3       0        1        4        8    1142.988
# 4       0        0       29       29    6811.372

# %%
user_data.to_csv("user_data.csv")

# %%
user_data.head(10)
# Out:
#                                            msno  city  age  registered_via  \
# 0  WH5Jq4mgtfUFXh2yz+HrcTXKS4Oess4k4W3qKolAeb0=     5   34               9
# 1  I0yFvqMoNkM8ZNHb617e1RBzIS/YRKemHO7Wj13EtA0=    13   63               9
# 2  I0yFvqMoNkM8ZNHb617e1RBzIS/YRKemHO7Wj13EtA0=    13   63               9
# 3  I0yFvqMoNkM8ZNHb617e1RBzIS/YRKemHO7Wj13EtA0=    13   63               9
# 4  I0yFvqMoNkM8ZNHb617e1RBzIS/YRKemHO7Wj13EtA0=    13   63               9
# 5  I0yFvqMoNkM8ZNHb617e1RBzIS/YRKemHO7Wj13EtA0=    13   63               9
# 6  I0yFvqMoNkM8ZNHb617e1RBzIS/YRKemHO7Wj13EtA0=    13   63               9
# 7  I0yFvqMoNkM8ZNHb617e1RBzIS/YRKemHO7Wj13EtA0=    13   63               9
# 8  OoDwiKZM+ZGr9P3fRivavgOtglTEaNfWJO4KaJcTTts=     1    0               7
# 9  OoDwiKZM+ZGr9P3fRivavgOtglTEaNfWJO4KaJcTTts=     1    0               7
#
#    registration_init_time  female  male  NaN      date  num_25  num_50  \
# 0                20110916       0     1    0  20161003       5       1
# 1                20110918       0     1    0  20150103       0       0
# 2                20110918       0     1    0  20150522       2       0
# 3                20110918       0     1    0  20151016       2       1
# 4                20110918       0     1    0  20160131       1       0
# 5                20110918       0     1    0  20160406       3       1
# 6                20110918       0     1    0  20160722       1       2
# 7                20110918       0     1    0  20161217       0       1
# 8                20110918       0     0    1  20150512      13       3
# 9                20110918       0     0    1  20151009       0       0
#
#    num_75  num_985  num_100  num_unq  total_secs
# 0       1        0       16       20    4294.178
# 1       0        0        1        1     229.616
# 2       0        1       18       19    4686.103
# 3       0        1        4        8    1142.988
# 4       0        0       29       29    6811.372
# 5       0        0       18       21    4801.824
# 6       0        0        0        3     227.775
# 7       0        1       13       15    3345.163
# 8       2        1       39       49   11349.136
# 9       0        0        3        3     741.903

# %%
# from sklearn.preprocessing import StandardScaler

# scaler = StandardScaler()
# scaler.fit()
# scaled_head = scaler.transform(user_data.head(10))

# %%
user_data.drop(columns=["msno"]).head(10)
